# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandu0444/Machine_learning/blob/main/linear_reg_practical1_MC(30_10_2025).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #linear regression practice with "boston" dataset(30-10-2025)

# %%
#reading the file
data=pd.read_csv('Boston.csv')

# %%
#importing required packages, libraries.
import numpy as np
import pandas as pd

#data visualization packages
import matplotlib.pyplot as plt
import seaborn as sns

#machine learning packages
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
data.shape
# Out:
# (506, 14)

# %%
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  black    506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %% [markdown]
# #check null values

# %%
data.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# #check the duplicate values present int the dataset or not

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
#if any duplicate values present remove them
#data.drop_duplicates(inplace=True)

# %% [markdown]
# #removing the outliers

# %%
def remove_outliers(data,columns):
  for col in columns:
    if col in data.columns:
      q1=data[col].quantile(0.25)
      q3=data[col].quantile(0.75)
      iq3=q3-q1
      lb=q1-1.5*iq3
      ub=q3+1.5*iq3
      data=data[(data[col]>=lb) & (data[col]<=ub)]
  return data

# %%
data_without_outlier=remove_outliers(data,data.columns)
data_without_outlier
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 5    0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222
# 6    0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# 7    0.14455  12.5   7.87     0  0.524  6.172  96.1  5.9505    5  311
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
data.shape
# Out:
# (506, 14)

# %% [markdown]
# creating input as 'x' and ouput as 'y'

# %%
x=data_without_outlier.drop('medv',axis=1) #storing inputs columns in 'x'
y=data_without_outlier['medv'] # storing output columns in y

# %%
data_without_outlier.shape
# Out:
# (214, 14)

# %% [markdown]
# #splitting data into training sets and testing tests

# %%
x_test, x_train, y_test, y_train=train_test_split(x,y,test_size=0.2,random_state=100)

# %%
lin_reg=LinearRegression()
lin_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lin_reg.coef_ #returns m1,m2,m3,.... values
# Out:
# array([ 1.05850636e+00, -9.80077999e-02, -1.81769798e-01, -3.68177711e-13,
#        -1.46952983e+01,  6.11308422e+00, -1.14745973e-02,  9.19655409e-02,
#        -2.58303250e-01, -5.69235850e-04, -7.04578566e-01, -8.89975122e-03,
#        -3.52268541e-02])

# %%
lin_reg.intercept_ #returns c value
# Out:
# np.float64(12.183952815045417)

# %%
y_test_pred=lin_reg.predict(x_test)
pd.DataFrame({'actual':y_test,'predicted':y_pred}).head()
# Out:
#      actual  predicted
# 6      22.9  22.283721
# 125    21.4  16.894978
# 110    21.7  20.406786
# 45     19.3  21.930168
# 499    17.5  16.080700

# %%
y_train_pred=lin_reg.predict(x_train)
pd.DataFrame({'actual':y_train,'predicted':y_train}).head()
# Out:
#      actual  predicted
# 178    29.9       29.9
# 302    26.4       26.4
# 246    24.3       24.3
# 231    31.7       31.7
# 173    23.6       23.6

# %% [markdown]
# #performance test by r2_score and mean squared error

# %%
r2_score(y_test,y_pred) #it should be <5
# Out:
# 0.4044394784491603

# %%
#calculate mean squared error
mse=mean_squared_error(y_test,y_test_pred)
mse
# Out:
# 9.431920555137053

# %%
#root mean squared error
rmse=np.sqrt(mse)
rmse
# Out:
# np.float64(3.071143200037578)
